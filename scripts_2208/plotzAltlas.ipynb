# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("eta_histo.txt") as f:
    data = f.read()

    lines = f.readlines()

    x = [line.split()[0] for line in lines]
    y = [line.split()[1] for line in lines]

    fig = plt.figure()

    ax1 = fig.add_subplot(111)

    ax1.set_title("Plot title")    
    ax1.set_xlabel('delta z ATLAS')
    ax1.set_ylabel('delta (delta Z)')

    ax1.plot(x,y, c='r', label='semi Scatter plot')

    leg = ax1.legend()

    plt.show()

# %% [markdown]
# ##

# %%
import pandas as pd
data = pd.read_csv('eta_histo.txt',sep='\s+',header=None)
data = pd.DataFrame(data)

import matplotlib.pyplot as plt
x = data[0]
y = data[1]
plt.plot(x, y,'r')
plt.show()

# %%
data = np.loadtxt('eta_histo.txt')


x = np.abs(data[:, 0])
y = (data[:, 1])
plt.plot((np.abs(x)), (np.abs(y)),'r.')
plt.xscale('log')
plt.yscale('log')

# %%
data1 = np.loadtxt('eta_histo.txt')

data2 = np.loadtxt('eta_histo2.txt')

x1 = np.abs(data1[:, 0])
y1 = (data1[:, 1])

x2 = np.abs(data2[:, 0])
y2 = (data2[:, 1])

y1_pos = y1[x1 > 10**(-3)]
x1_pos = x1[x1 > 10**(-3)]

y2_pos = y2[x2 > 10**(-3)]
x2_pos = x2[x2 > 10**(-3)]

plt.plot((np.abs(x1_pos)), (np.abs(y1_pos)),'r.', alpha=0.5)
plt.plot((np.abs(x2_pos)), (np.abs(y2_pos)),'b.', alpha=0.5)
plt.xscale('log')
plt.yscale('log')

# %%
data1 = np.loadtxt('eta_histo.txt')

x1 = np.abs(data1[:, 0])
y1 = (data1[:, 1])

y1_pos = y1[x1 > 10**(-3)]
x1_pos = x1[x1 > 10**(-3)]


plt.plot((np.abs(x1_pos)), (np.abs(y1_pos)),'r.')
plt.xscale('log')
plt.yscale('log')

# %%
print(np.max(np.abs(x)))
print(np.min(np.abs(x)))
# Out:
# 4509.648348276886
# 1.190761662751884e-12

# %%
print(np.max(np.abs(x2)))
print(np.min(np.abs(x2)))
# Out:
# 4509.648348276886
# 1.190761662751884e-12

# %%
print(np.max(np.abs(y)))
print(np.min(np.abs(y)))
# Out:
# 118.42404598048294
# 0.0

# %%
print(np.max(np.abs(y2)))
print(np.min(np.abs(y2)))
# Out:
# 118.42404598048294
# 0.0

# %%
len(x1)
# Out:
# 17086

# %%
len(x2)
# Out:
# 6047
